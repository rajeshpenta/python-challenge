# %%
# *  According to this this data it would see that young kids 10 and under are not thrifty and do not care about their parents
# money becuase they have they pay the highest average purchase price ($3.01), beating out older demographics.
#
# *  Final Artic seems to favorite weapon among players being purchased 14 times and the most frequent of any weapon 
#
# *  This game seems to be pretty heavily male dominant at 81%. Maybe more resouces could be put into advertising towards woman or 
#    the game could be changed to be more welcoming to female players.
# 
# 
#

# %%
# import dependencies
import pandas as pd
import numpy as np

# %%
#Print out entire data frames to see what we are dealing with
df=pd.read_json('/Users/BillyRay/Desktop/purchase_data.json')
df
# Out:
#      Age                 Gender  Item ID  \
# 0     38                   Male      165
# 1     21                   Male      119
# 2     34                   Male      174
# 3     21                   Male       92
# 4     23                   Male       63
# 5     20                   Male       10
# 6     20                   Male      153
# 7     29                 Female      169
# 8     25                   Male      118
# 9     31                   Male       99
# 10    24                   Male       57
# 11    20                   Male       47
# 12    30                   Male       81
# 13    23                   Male       77
# 14    40                   Male       44
# 15    21                   Male       96
# 16    22                 Female      123
# 17    22                 Female       59
# 18    28                   Male       91
# 19    31                   Male      177
# 20    24                   Male       78
# 21    15                   Male        3
# ...

# %%
#Find unique screen names
unique_SN=df["SN"].unique()
unique_SN
# Out:
# array(['Aelalis34', 'Eolo46', 'Assastnya25', 'Pheusrical25', 'Aela59',
#        'Tanimnya91', 'Undjaskla97', 'Iathenudil29', 'Sondenasta63',
#        'Hilaerin92', 'Chamosia29', 'Sally64', 'Iskossa88',
#        'Seorithstilis90', 'Sundast29', 'Haellysu29', 'Sundista85',
#        'Aenarap34', 'Iskista88', 'Assossa43', 'Irith83', 'Iaralrgue74',
#        'Deural48', 'Chanosia65', 'Qarwen67', 'Idai61', 'Aerithllora36',
#        'Ilariarin45', 'Phaedai25', 'Eulaeria40', 'Iarilis73', 'Malunil62',
#        'Iskimnya76', 'Yararmol43', 'Aisur51', 'Undare39', 'Sondossa91',
#        'Chamjasknya65', 'Lassilsa63', 'Tyisur83', 'Aeral43',
#        'Lassadarsda57', 'Alaephos75', 'Frichjask31', 'Eusur90',
#        'Palatyon26', 'Saellyra72', 'Ililsa62', 'Eosur70', 'Saistyphos30',
#        'Reula64', 'Chanirrala39', 'Chadanto83', 'Minduli80', 'Heunadil74',
#        'Marilsasya33', 'Alallo58', 'Tyaeristi78', 'Ila44', 'Iskossaya95',
# ...

# %%
# Count how many Screen names there are to see how many players
SN_Value_Count=df["SN"].value_counts()
SN_Value_Count
# Out:
# Undirrala66        5
# Saedue76           4
# Mindimnya67        4
# Hailaphos89        4
# Sondastan54        4
# Qarwen67           4
# Lirtosia72         3
# Frichaya88         3
# Ialistidru50       3
# Frichosiala98      3
# Aduephos78         3
# Eusri70            3
# Mindirra92         3
# Chamistast30       3
# Chanastsda67       3
# Tillyrin30         3
# Haellysu29         3
# Aerithllora36      3
# Lisistaya47        3
# Chadjask77         3
# Eoda93             3
# Yasriphos60        3
# Isursti83          3
# Sondim43           3
# Yadanun74          3
# Chadossa56         3
# Lisossa63          3
# Seorithstilis90    3
# Isurria36          3
# Ila44              3
#                   ..
# Eryon48            1
# Tyida79            1
# Eosursurap97       1
# Ililsan66          1
# Qaronon57          1
# Mindosiasya28      1
# Jiskirran77        1
# Reolacal36         1
# Ilrian97           1
# Raedalis34         1
# Ialo60             1
# Reulae52           1
# ...

# %%
# display total number of players in a chart
Total_Players = pd.DataFrame({'Total Players': [573]})

Total_Players
# Out:
#    Total Players
# 0            573

# %%
########################################### Purchasing Analysis #####################################################

# %%
# array of each item ID that was purchased
unique_itemID=df["Item ID"].unique()
unique_itemID
# Out:
# array([165, 119, 174,  92,  63,  10, 153, 169, 118,  99,  57,  47,  81,
#         77,  44,  96, 123,  59,  91, 177,  78,   3,  11, 183,  65, 132,
#        106,  49,  45, 155,  37,  48,  90,  13, 171,  25,   7, 124,  68,
#         85, 120,  17, 141,  73, 151,  32,  51, 101, 140,  31,  34,   2,
#         86,  39,  28, 160, 134,  83,  38, 158, 110, 122,  54, 105,  87,
#         23, 144, 128, 175,  46, 150, 152, 108, 172, 167, 181,  20, 130,
#        111, 103,  30, 139, 173,  55, 115,  35,  42,   9,  84, 180, 102,
#         53,  18,  74, 126,  50,  62, 125, 121, 129, 149,  12,  71,  14,
#         58,  27,  52,  66, 100, 112,  24,  94, 107,   0, 182,  97,  70,
#         89,   1, 170,  93, 179,  36,  75, 143, 137, 176, 148, 127, 147,
#        161, 154, 157, 116,  61, 131,  41, 145,  60, 162, 135,   8,  40,
#         15,  29,  72, 114, 117,  79,  88, 104,  95,  64,  98,  33,  76,
#        146, 166,  56,  22,  21,  16,  67, 133,  69, 159,  82, 113, 164,
# ...

# %%
# Find the total amount of unique items
df["Item ID"].value_counts()
# Out:
# 84     11
# 39     11
# 31      9
# 34      9
# 175     9
# 13      9
# 106     8
# 44      8
# 92      8
# 65      8
# 152     8
# 107     8
# 172     7
# 179     7
# 115     7
# 154     7
# 79      7
# 158     7
# 108     7
# 66      7
# 11      7
# 130     7
# 18      7
# 124     6
# 103     6
# 101     6
# 121     6
# 102     6
# 73      6
# 145     6
#        ..
# 116     2
# 89      2
# 64      2
# 9       2
# 167     2
# 80      2
# 74      2
# 72      2
# 146     2
# 149     2
# 150     2
# 178     2
# 62      2
# 58      2
# 56      2
# 55      2
# 4       1
# 2       1
# 3       1
# 59      1
# 28      1
# 168     1
# 164     1
# 43      1
# 156     1
# 147     1
# 136     1
# 126     1
# 109     1
# 0       1
# Name: Item ID, Length: 183, dtype: int64

# %%
#find the average purchase price and total number of purchases
df.describe()
# Out:
#               Age     Item ID       Price
# count  780.000000  780.000000  780.000000
# mean    22.729487   91.293590    2.931192
# std      6.930604   52.707537    1.115780
# min      7.000000    0.000000    1.030000
# 25%     19.000000   44.000000    1.960000
# 50%     22.000000   91.000000    2.880000
# 75%     25.000000  135.000000    3.910000
# max     45.000000  183.000000    4.950000

# %%
# Determine the total revenue by adding up the "Price" column
df["Price"].sum()
# Out:
# 2286.33

# %%
# display chart of purchasing analysis
Purchasing_Analysis = {'Number of Unique Items': [183], 
                       'Average Price': ['$2.93'],
                        "Number of Purchases": [780], 
                        "Total Revenue": ['$2286.33']}
df = pd.DataFrame.from_dict(Purchasing_Analysis, orient='index')
df.transpose()
# Out:
#   Number of Unique Items Average Price Number of Purchases Total Revenue
# 0                    183         $2.93                 780      $2286.33

# %%
########################################### Gender Demographic #######################################################

# %%
# finding out the value count for each catagory of genders
gender_purchase_count=df["Gender"].value_counts()
gender_purchase_count
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'Gender'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
#display gender count and percentage chart
Gender_Demo = pd.DataFrame({
   'Percentage of Players': [81.15, 17.45, 1.40],
   'Total Count': [465, 100, 8], 'Gender'  : ['Male', 'Female', 'Other / Non-Disclosed']})

Gender_Demo
# Out:
#                   Gender  Percentage of Players  Total Count
# 0                   Male                  81.15          465
# 1                 Female                  17.45          100
# 2  Other / Non-Disclosed                   1.40            8

# %%
# looking at info for just males
male_stripped=df.loc[df['Gender'] == 'Male']
male_stripped
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'Gender'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
# Finding the male average purchase count
male_avg_purchase_count=male_stripped["Price"].mean()
male_avg_purchase_count
# Out:
# 2.9505213270142154

# %%
# Calculatiing total purchase count for males
male_total_purchase_count=male_stripped["Price"].sum()
male_total_purchase_count
# Out:
# 1867.68

# %%
# looking at info on just females
female_stripped=df.loc[df['Gender'] == 'Female']
female_stripped
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# /Applications/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 'Gender'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
# Finding the female average purchase count
female_avg_purchase_count=female_stripped["Price"].mean()
female_avg_purchase_count
# Out:
# 2.815514705882352

# %%
# Calculatiing total purchase count for females
female_total_purchase_count=female_stripped["Price"].sum()
female_total_purchase_count
# Out:
# 382.90999999999997

# %%
# looking at just the stats for other
other_stripped=df.loc[df['Gender'] == 'Other / Non-Disclosed']
other_stripped
# Out:
#      Age                 Gender  Item ID                        Item Name  \
# 177   34  Other / Non-Disclosed      155        War-Forged Gold Deflector
# 209   33  Other / Non-Disclosed      157          Spada, Etcher of Hatred
# 244   21  Other / Non-Disclosed      183              Dragon's Greatsword
# 267   33  Other / Non-Disclosed       65        Conqueror Adamantite Mace
# 276   12  Other / Non-Disclosed      128    Blazeguard, Reach of Eternity
# 298   26  Other / Non-Disclosed      141                       Persuasion
# 329   27  Other / Non-Disclosed       61                         Ragnarok
# 423   32  Other / Non-Disclosed       29          Chaos, Ender of the End
# 593   22  Other / Non-Disclosed      115       Spectral Diamond Doomblade
# 709   34  Other / Non-Disclosed      179  Wolf, Promise of the Moonwalker
# 763   27  Other / Non-Disclosed       48  Rage, Legacy of the Lone Victor
#
#      Price              SN Age Group
# 177   3.73       Assassa38      >=30
# ...

# %%
# Finding the other average purchase count
other_avg_purchase_count=other_stripped["Price"].mean()
other_avg_purchase_count
# Out:
# 3.2490909090909086

# %%
# Calculatiing total purchase count for other
other_total_purchase_count=other_stripped["Price"].sum()
other_total_purchase_count
# Out:
# 35.739999999999995

# %%
# display purchasing analysis chart
Purchasing_Analysis = pd.DataFrame({
   'Purchase Count': [633, 136, 11],
   'Average Purchase Price': ['$2.95', '$2.81', '$3.24'],
   'Total Purchase Value': ['$1,867.68', '$$382.91', '$35.73'],
   'Gender'  : ['Male', 'Female', 'Other / Non-Disclosed']})

Purchasing_Analysis
# Out:
#   Average Purchase Price                 Gender  Purchase Count  \
# 0                  $2.95                   Male             633
# 1                  $2.81                 Female             136
# 2                  $3.24  Other / Non-Disclosed              11
#
#   Total Purchase Value
# 0            $1,867.68
# 1             $$382.91
# 2               $35.73

# %%
############################################ Age Demographics #########################################################

# %%
#Find the lowest age to determine what would be the proper bins
df["Age"].min()
# Out:
# 7

# %%
#Find the highest age to determine what would be the proper bins
df["Age"].max()
# Out:
# 45

# %%
#Create Bins
bins = [0, 10, 20, 30, 200,]

# create labeels for bins
group_names = ["=<10", "10-20", "20-30", ">=30"]

# %%
df["Age Group"] = pd.cut(df["Age"], bins, labels=group_names)
df
# Out:
#      Age                 Gender  Item ID  \
# 0     38                   Male      165
# 1     21                   Male      119
# 2     34                   Male      174
# 3     21                   Male       92
# 4     23                   Male       63
# 5     20                   Male       10
# 6     20                   Male      153
# 7     29                 Female      169
# 8     25                   Male      118
# 9     31                   Male       99
# 10    24                   Male       57
# 11    20                   Male       47
# 12    30                   Male       81
# 13    23                   Male       77
# 14    40                   Male       44
# 15    21                   Male       96
# 16    22                 Female      123
# 17    22                 Female       59
# 18    28                   Male       91
# 19    31                   Male      177
# 20    24                   Male       78
# 21    15                   Male        3
# ...

# %%
df["Age Group"].value_counts()
# Out:
# 20-30    381
# 10-20    262
# >=30     105
# =<10      32
# Name: Age Group, dtype: int64

# %%
#10 and under stripped
bin10and_under_stripped=df.loc[df['Age Group'] == '=<10']
bin10and_under_stripped
# Out:
#      Age  Gender  Item ID                                 Item Name  Price  \
# 70     7  Female      158        Darkheart, Butcher of the Champion   3.56
# 121    7    Male      175                Woeful Adamantite Claymore   1.24
# 125    7  Female       10                               Sleepwalker   1.73
# 170    9    Male       71                                    Demise   4.07
# 237    7    Male      121                                  Massacre   3.42
# 260    9    Male       99      Expiration, Warscythe Of Lost Worlds   4.53
# 271    7    Male       77                Piety, Guardian of Riddles   3.68
# 289    8    Male       79                       Alpha, Oath of Zeal   2.88
# 291    7    Male       53                         Vengeance Cleaver   3.70
# 292    7    Male      121                                  Massacre   3.42
# 360    7  Female       21                                 Souleater   3.27
# ...

# %%
# 10 and under average purchase price
avg_pur_price_10and_under = bin10and_under_stripped["Price"].mean()
avg_pur_price_10and_under
# Out:
# 3.0193749999999993

# %%
# 10 and under Total purchase value
total_purchase_value_10and_under = bin10and_under_stripped["Price"].sum()
total_purchase_value_10and_under
# Out:
# 96.62

# %%
#10-20 stripped
bin10_20_stripped=df.loc[df['Age Group'] == '10-20']
bin10_20_stripped
# Out:
#      Age  Gender  Item ID                               Item Name  Price  \
# 5     20    Male       10                             Sleepwalker   1.73
# 6     20    Male      153                         Mercenary Sabre   4.57
# 11    20    Male       47             Alpha, Reach of Ending Hope   1.55
# 21    15    Male        3                            Phantomlight   1.79
# 22    11  Female       11                               Brimstone   2.52
# 23    19    Male      183                     Dragon's Greatsword   2.36
# 24    11    Male       65               Conqueror Adamantite Mace   1.96
# 28    15    Male       49        The Oculus, Token of Lost Worlds   4.23
# 29    16  Female       45                     Glinting Glass Edge   2.46
# 31    18    Male       37     Shadow Strike, Glory of Ending Hope   1.93
# 32    19    Male       48         Rage, Legacy of the Lone Victor   4.32
# 36    20    Male       44                   Bonecarvin Battle Axe   2.46
# ...

# %%
#10-20 average purchase price
avg_pur_price_10_20 = bin10_20_stripped["Price"].mean()
avg_pur_price_10_20
# Out:
# 2.873625954198474

# %%
#10-20 Total purchase value
total_purchase_value_10_20 = bin10_20_stripped["Price"].sum()
total_purchase_value_10_20
# Out:
# 752.89

# %%
#20-30 stripped
bin20_30_stripped=df.loc[df['Age Group'] == '20-30']
bin20_30_stripped
# Out:
#      Age                 Gender  Item ID  \
# 1     21                   Male      119
# 3     21                   Male       92
# 4     23                   Male       63
# 7     29                 Female      169
# 8     25                   Male      118
# 10    24                   Male       57
# 12    30                   Male       81
# 13    23                   Male       77
# 15    21                   Male       96
# 16    22                 Female      123
# 17    22                 Female       59
# 18    28                   Male       91
# 20    24                   Male       78
# 25    21                   Male       63
# 26    29                   Male      132
# 30    21                 Female      155
# 33    24                   Male       90
# 34    22                   Male       47
# 35    21                 Female       13
# 39    23                   Male       63
# 42    24                   Male       25
# 43    22                   Male       68
# ...

# %%
#20-30 average purchase price
avg_pur_price_20to30 = bin20_30_stripped["Price"].mean()
avg_pur_price_20to30
# Out:
# 2.9460104986876647

# %%
#20-30 Total purchase value
total_purchase_value_20to30 = bin20_30_stripped["Price"].sum()
total_purchase_value_20to30
# Out:
# 1122.43

# %%
#30 and older stripped
bin_30andup_stripped=df.loc[df['Age Group'] == '>=30']
bin_30andup_stripped
# Out:
#      Age                 Gender  Item ID  \
# 0     38                   Male      165
# 2     34                   Male      174
# 9     31                   Male       99
# 14    40                   Male       44
# 19    31                   Male      177
# 27    34                   Male      106
# 37    31                   Male      171
# 40    32                   Male        7
# 50    32                 Female       32
# 60    31                   Male       86
# 72    34                   Male      110
# 75    31                   Male       31
# 81    38                   Male      175
# 90    33                   Male       91
# 104   34                   Male      173
# 106   37                 Female      174
# 120   31                   Male      102
# 175   35                   Male       34
# 177   34  Other / Non-Disclosed      155
# 179   40                   Male       70
# 186   40                   Male      144
# 189   35                   Male      179
# ...

# %%
#30 and up average purchase price
avg_pur_price_30andup = bin_30andup_stripped["Price"].mean()
avg_pur_price_30andup
# Out:
# 2.9941904761904765

# %%
#30 and up Total purchase value
total_purchase_value_30andup = bin_30andup_stripped["Price"].sum()
total_purchase_value_30andup
# Out:
# 314.39

# %%
Age_Demo = pd.DataFrame({
   'Percentage of Players': [3.32, 4.01, 17.45, 45.20, 15.18, 8.20, 4.71, 1.92],
   'Total Count': [19, 23, 100, 259, 87, 47, 27, 11],
   'Age Range'  : ['<10', '10-14', '15-19','20-24','25-29','30-34','35-39','40+']})
Age_Demo
# Out:
#   Age Range  Percentage of Players  Total Count
# 0       <10                   3.32           19
# 1     10-14                   4.01           23
# 2     15-19                  17.45          100
# 3     20-24                  45.20          259
# 4     25-29                  15.18           87
# 5     30-34                   8.20           47
# 6     35-39                   4.71           27
# 7       40+                   1.92           11

# %%
###################################### TOP SPENDERS ###################################################################

# %%
# finding out who the top spenders are by total purchases
SN_Value_Count=df["SN"].value_counts()
SN_Value_Count
# Out:
# Undirrala66        5
# Saedue76           4
# Mindimnya67        4
# Hailaphos89        4
# Sondastan54        4
# Qarwen67           4
# Lirtosia72         3
# Frichaya88         3
# Ialistidru50       3
# Frichosiala98      3
# Aduephos78         3
# Eusri70            3
# Mindirra92         3
# Chamistast30       3
# Chanastsda67       3
# Tillyrin30         3
# Haellysu29         3
# Aerithllora36      3
# Lisistaya47        3
# Chadjask77         3
# Eoda93             3
# Yasriphos60        3
# Isursti83          3
# Sondim43           3
# Yadanun74          3
# Chadossa56         3
# Lisossa63          3
# Seorithstilis90    3
# Isurria36          3
# Ila44              3
#                   ..
# Eryon48            1
# Tyida79            1
# Eosursurap97       1
# Ililsan66          1
# Qaronon57          1
# Mindosiasya28      1
# Jiskirran77        1
# Reolacal36         1
# Ilrian97           1
# Raedalis34         1
# Ialo60             1
# Reulae52           1
# ...

# %%
# Isolating top spender #1
top_spender_1=df.loc[df['SN'] == 'Undirrala66']
top_spender_1
# Out:
#      Age Gender  Item ID                   Item Name  Price           SN  \
# 79    29   Male      144      Blood Infused Guardian   2.86  Undirrala66
# 107   29   Male      115  Spectral Diamond Doomblade   4.25  Undirrala66
# 131   29   Male       62                 Piece Maker   4.36  Undirrala66
# 537   29   Male       18  Torchlight, Bond of Storms   1.77  Undirrala66
# 596   29   Male      133            Faith's Scimitar   3.82  Undirrala66
#
#     Age Group
# 79      20-30
# 107     20-30
# 131     20-30
# 537     20-30
# 596     20-30

# %%
# top spender #1 average purchase price
top_spender_1_avg_pur_price=top_spender_1["Price"].mean()
top_spender_1_avg_pur_price
# Out:
# 3.412

# %%
# top spender #1 total purchase value
top_spender_1_total_pur_val=top_spender_1["Price"].sum()
top_spender_1_total_pur_val
# Out:
# 17.06

# %%
# Isolating top spender #2
top_spender_2=df.loc[df['SN'] == 'Saedue76']
top_spender_2
# Out:
#      Age Gender  Item ID                     Item Name  Price        SN  \
# 259   25   Male       13                      Serenity   1.49  Saedue76
# 337   25   Male      140                       Striker   3.82  Saedue76
# 411   25   Male        7  Thorn, Satchel of Dark Souls   4.51  Saedue76
# 708   25   Male       73                   Ritual Mace   3.74  Saedue76
#
#     Age Group
# 259     20-30
# 337     20-30
# 411     20-30
# 708     20-30

# %%
# top spender #2 avg purchase price
top_spender_2_avg_pur_price=top_spender_2["Price"].mean()
top_spender_2_avg_pur_price
# Out:
# 3.39

# %%
# top spender #2 total purchase value
top_spender_2_total_pur_val=top_spender_2["Price"].sum()
top_spender_2_total_pur_val
# Out:
# 13.56

# %%
# Isolating top spender #3
top_spender_3=df.loc[df['SN'] == 'Mindimnya67']
top_spender_3
# Out:
#      Age  Gender  Item ID             Item Name  Price           SN Age Group
# 450   39  Female      140               Striker   3.82  Mindimnya67      >=30
# 464   39  Female      163  Thunderfury Scimitar   3.02  Mindimnya67      >=30
# 592   39  Female      145  Fiery Glass Crusader   4.45  Mindimnya67      >=30
# 623   39  Female      161                Devine   1.45  Mindimnya67      >=30

# %%
# top spender #3 average purchase price
top_spender_3_avg_pur_price=top_spender_3["Price"].mean()
top_spender_3_avg_pur_price
# Out:
# 3.1849999999999996

# %%
# top spender #3 purchase value
top_spender_3_total_pur_val=top_spender_3["Price"].sum()
top_spender_3_total_pur_val
# Out:
# 12.739999999999998

# %%
# Isolating top spender #4
top_spender_4=df.loc[df['SN'] == 'Hailaphos89']
top_spender_4
# Out:
#      Age Gender  Item ID         Item Name  Price           SN Age Group
# 93    20   Male       20        Netherbane   1.48  Hailaphos89     10-20
# 218   20   Male       31         Trickster   2.07  Hailaphos89     10-20
# 429   20   Male       82           Nirvana   1.11  Hailaphos89     10-20
# 767   20   Male      122  Unending Tyranny   1.21  Hailaphos89     10-20

# %%
# top spender #4 avg purchase price
top_spender_4_avg_pur_price=top_spender_4["Price"].mean()
top_spender_4_avg_pur_price
# Out:
# 1.4675

# %%
# top spender #4 total purchase value
top_spender_4_total_pur_val=top_spender_4["Price"].sum()
top_spender_4_total_pur_val
# Out:
# 5.87

# %%
# Isolating top spender #5
top_spender_5=df.loc[df['SN'] == 'Sondastan54']
top_spender_5
# Out:
#      Age Gender  Item ID            Item Name  Price           SN Age Group
# 75    31   Male       31            Trickster   2.07  Sondastan54      >=30
# 304   31   Male      173  Stormfury Longsword   4.83  Sondastan54      >=30
# 420   31   Male      170          Shadowsteel   1.98  Sondastan54      >=30
# 754   31   Male      104   Gladiator's Glaive   1.36  Sondastan54      >=30

# %%
# top spender #5 avgerage purchase price
top_spender_5_avg_pur_price=top_spender_5["Price"].mean()
top_spender_5_avg_pur_price
# Out:
# 2.56

# %%
# top spender #5 total purchase value
top_spender_5_total_pur_val=top_spender_5["Price"].sum()
top_spender_5_total_pur_val
# Out:
# 10.24

# %% [markdown]
# ################################## MOST POPULAR ITEM ############################################################

# %%
# identifying most popular item by puchase count
SN_Value_Count=df["Item Name"].value_counts()
SN_Value_Count
# Out:
# Final Critic                                    14
# Arcane Gem                                      11
# Betrayal, Whisper of Grieving Widows            11
# Stormcaller                                     10
# Woeful Adamantite Claymore                       9
# Retribution Axe                                  9
# Serenity                                         9
# Trickster                                        9
# Crucifer                                         8
# Splitter, Foe Of Subtlety                        8
# Conqueror Adamantite Mace                        8
# Bonecarvin Battle Axe                            8
# Darkheart                                        8
# Crying Steel Sickle                              8
# Blade of the Grave                               7
# Wolf, Promise of the Moonwalker                  7
# Spectral Diamond Doomblade                       7
# Feral Katana                                     7
# ...

# %%
# Isolating most popular item #1
most_popular_item_1=df.loc[df['Item Name'] == 'Final Critic']
most_popular_item_1
# Out:
#      Age  Gender  Item ID     Item Name  Price            SN Age Group
# 3     21    Male       92  Final Critic   1.36  Pheusrical25     20-30
# 54    25  Female      101  Final Critic   4.62     Minduli80     20-30
# 193   19    Male      101  Final Critic   4.62   Farusrian86     10-20
# 226   25  Female       92  Final Critic   1.36  Chamistast30     20-30
# 415   25  Female       92  Final Critic   1.36  Chamistast30     20-30
# 431   37    Male       92  Final Critic   1.36    Aduephos78      >=30
# 458   25    Male       92  Final Critic   1.36    Jiskassa76     20-30
# 509   28    Male       92  Final Critic   1.36     Iskista88     20-30
# 572   24    Male       92  Final Critic   1.36     Lisossa63     20-30
# 606   20    Male      101  Final Critic   4.62    Lirtossa84     10-20
# 612   18  Female      101  Final Critic   4.62     Isurria36     10-20
# 648   23    Male       92  Final Critic   1.36       Rithe53     20-30
# ...

# %%
# most popular iteam #1 purchase value
most_popular_item_1_total_pur_val=most_popular_item_1["Price"].sum()
most_popular_item_1_total_pur_val
# Out:
# 38.599999999999994

# %%
# Isolating most popular item #2
most_popular_item_2=df.loc[df['Item Name'] == 'Arcane Gem']
most_popular_item_2
# Out:
#      Age  Gender  Item ID   Item Name  Price             SN Age Group
# 116   25    Male       84  Arcane Gem   2.23     Koikirra25     20-30
# 171   21    Male       84  Arcane Gem   2.23  Stryanastip77     20-30
# 297   24    Male       84  Arcane Gem   2.23     Yarolwen77     20-30
# 338   17    Male       84  Arcane Gem   2.23   Lisossanya98     10-20
# 354   20    Male       84  Arcane Gem   2.23     Mindirra92     10-20
# 416   25    Male       84  Arcane Gem   2.23     Hiarideu73     20-30
# 440   21    Male       84  Arcane Gem   2.23  Stryanastip77     20-30
# 541   20    Male       84  Arcane Gem   2.23   Eosursurap97     10-20
# 711   22    Male       84  Arcane Gem   2.23  Tyananurgue44     20-30
# 742   26    Male       84  Arcane Gem   2.23      Inguron55     20-30
# 766   22  Female       84  Arcane Gem   2.23    Nitherian58     20-30

# %%
# most popular item #2 total purchase value
most_popular_item_2_total_pur_val=most_popular_item_2["Price"].sum()
most_popular_item_2_total_pur_val
# Out:
# 24.53

# %%
# Isolating most popular item #3
most_popular_item_3=df.loc[df['Item Name'] == 'Betrayal, Whisper of Grieving Widows']
most_popular_item_3
# Out:
#      Age  Gender  Item ID                             Item Name  Price  \
# 61    24    Male       39  Betrayal, Whisper of Grieving Widows   2.35
# 62    19  Female       39  Betrayal, Whisper of Grieving Widows   2.35
# 154   27  Female       39  Betrayal, Whisper of Grieving Widows   2.35
# 194   24    Male       39  Betrayal, Whisper of Grieving Widows   2.35
# 361   14    Male       39  Betrayal, Whisper of Grieving Widows   2.35
# 362   36    Male       39  Betrayal, Whisper of Grieving Widows   2.35
# 382   25    Male       39  Betrayal, Whisper of Grieving Widows   2.35
# 406   24    Male       39  Betrayal, Whisper of Grieving Widows   2.35
# 554    7    Male       39  Betrayal, Whisper of Grieving Widows   2.35
# 574    7    Male       39  Betrayal, Whisper of Grieving Widows   2.35
# 721   26    Male       39  Betrayal, Whisper of Grieving Widows   2.35
#
#                SN Age Group
# 61   Rinallorap73     20-30
# 62         Aeri84     10-20
# ...

# %%
# most popular item #3 total purchase value
most_popular_item_3_total_pur_val=most_popular_item_3["Price"].sum()
most_popular_item_3_total_pur_val
# Out:
# 25.850000000000005

# %%
# Isolating most popular item #4
most_popular_item_4=df.loc[df['Item Name'] == 'Stormcaller']
most_popular_item_4
# Out:
#      Age  Gender  Item ID    Item Name  Price            SN Age Group
# 101   25    Male       30  Stormcaller   4.15  Assistasda90     20-30
# 119   19    Male      180  Stormcaller   2.78       Yasur35     10-20
# 199   30  Female      180  Stormcaller   2.78      Phadai31     20-30
# 307   26    Male      180  Stormcaller   2.78      Aidain51     20-30
# 333   22    Male       30  Stormcaller   4.15      Aeliru63     20-30
# 433   23    Male      180  Stormcaller   2.78  Ithesuphos68     20-30
# 506   29    Male      180  Stormcaller   2.78    Tyalaesu89     20-30
# 535   23  Female       30  Stormcaller   4.15     Undirra73     20-30
# 557   24    Male       30  Stormcaller   4.15    Iskimnya76     20-30
# 595   20    Male       30  Stormcaller   4.15       Eusur90     10-20

# %%
most popular item #4 total purchase value
most_popular_item_4_total_pur_val=most_popular_item_4["Price"].sum()
most_popular_item_4_total_pur_val
# Out:
# 34.65

# %%
# Isolating most popular item #5
most_popular_item_5=df.loc[df['Item Name'] == 'Woeful Adamantite Claymore']
most_popular_item_5
# Out:
#      Age  Gender  Item ID                   Item Name  Price             SN  \
# 81    38    Male      175  Woeful Adamantite Claymore   1.24      Yaristi64
# 121    7    Male      175  Woeful Adamantite Claymore   1.24     Lassjask63
# 143   15    Male      175  Woeful Adamantite Claymore   1.24   Quarusrion32
# 149   13    Male      175  Woeful Adamantite Claymore   1.24       Ilrian97
# 428   37  Female      175  Woeful Adamantite Claymore   1.24     Chadossa56
# 555   19    Male      175  Woeful Adamantite Claymore   1.24      Ialidru40
# 611   22    Male      175  Woeful Adamantite Claymore   1.24        Heolo60
# 734   13    Male      175  Woeful Adamantite Claymore   1.24  Mindosiasya28
# 761   28    Male      175  Woeful Adamantite Claymore   1.24    Raeduerin33
#
#     Age Group
# 81       >=30
# 121      =<10
# 143     10-20
# 149     10-20
# 428      >=30
# 555     10-20
# 611     20-30
# 734     10-20
# 761     20-30

# %%
# most popular item #5 total purchase value
most_popular_item_5_total_pur_val=most_popular_item_5["Price"].sum()
most_popular_item_5_total_pur_val
# Out:
# 11.16

# %%
################################ Most Profitable Items##############################################################

# %%
 # Create new table
profitable_items_frame = df[["Item ID", "Item Name","Price"]]
profitable_items_frame
# Out:
#      Item ID                                  Item Name  Price
# 0        165                Bone Crushing Silver Skewer   3.37
# 1        119  Stormbringer, Dark Blade of Ending Misery   2.32
# 2        174                            Primitive Blade   2.46
# 3         92                               Final Critic   1.36
# 4         63                             Stormfury Mace   1.27
# 5         10                                Sleepwalker   1.73
# 6        153                            Mercenary Sabre   4.57
# 7        169     Interrogator, Blood Blade of the Queen   3.32
# 8        118           Ghost Reaver, Longsword of Magic   2.77
# 9         99       Expiration, Warscythe Of Lost Worlds   4.53
# 10        57            Despair, Favor of Due Diligence   3.81
# 11        47                Alpha, Reach of Ending Hope   1.55
# 12        81                                  Dreamkiss   4.06
# 13        77                 Piety, Guardian of Riddles   3.68
# ...
